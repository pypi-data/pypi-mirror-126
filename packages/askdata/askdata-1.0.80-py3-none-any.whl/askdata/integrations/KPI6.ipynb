# %%
#Askdata SDK
# !pip install git+https://simonedisomma:Stralis26%24@bitbucket.org/innaasdev/askdata-api-python-client.git
# Out:
# ...
#   Cloning https://simonedisomma:****@bitbucket.org/innaasdev/askdata-api-python-client.git to /tmp/pip-req-build-4ixcfx7d
#   Running command git clone -q https://simonedisomma:Stralis26%24@bitbucket.org/innaasdev/askdata-api-python-client.git /tmp/pip-req-build-4ixcfx7d
# ...
#   Using cached https://files.pythonhosted.org/packages/0c/7d/9f085bbc9e209336d2849372472786698dff2371004b147a1ad4e4c52470/yaml_1.3-0.1.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/5c/8d/81d91c13e7f358e8c2b84730d5c09aec1dbbcf190e5b64c41cc5c67dfa4a/SQLAlchemy-1.3.17-cp37-cp37m-manylinux2010_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/72/1f/c668366b57f9826b2d5c365e25b51f0d55bd3ee734be5f6ad3950ecdef87/ruamel.appconfig-0.5.4-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/96/27/fc82d0e3e456c0dd60c65972775179beced772f07c97fbefcde55993b9bd/ruamel.std.argparse-0.8.3-py2.py3-none-any.whl
# ...

# %%
#static variable
base_url = 'https://api.kpi6.com'

#dynamic parameters from the dataset configuration
kpi6_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InMuZGlzb21tYUBhc2tkYXRhLmNvbSIsInJvbGUiOiJ1c2VyIiwiaWF0IjoxNTkzMDAwNzE3LCJleHAiOjE2MjQ1MzY3MTd9.ggF9Nn76xlb2C8d0icitRTRuL6iKjpPdSVhhCXTWdJU'
research_id = 'c7faa9e7-acc5-41ec-b1b7-d7341c952390'

#static for the workflow
path = '/usr/local/airflow/dags/workflow/'

#the token value and the agent_id are replaced on runtime
token = 'fcc3fd9c-9d1c-415a-bc2c-1c335e1ffea1'
agentId = 'be0783ab-884b-4af6-b5c9-aa074111aadb'

# %%
#initialization of the security
import pandas as pd
import requests

headers = {'content-type': 'application/json', 'Accept':'application/json', 'Authorization':'Bearer ' + kpi6_token}

# %%
x = requests.get(base_url + '/researches', headers=headers)

#use topic ID to get top words
x = requests.post(base_url + '/research/ '+ research_id + '/topwords', headers=headers)
# Out:
# {"type":"success","handler":"success_example_topic_list","value":[{"social":"twitter","topic_type":"search","stop_date":1522421600000,"created_at":1522314261319,"queries":[{"name":"Kellogg's","id":3733,"custom_color":"#1E7BF4","sources":{"twitter":{"gniptext":"(kelloggs OR kellogs OR barrette OR \"barrette cereali\" OR \"barrette mandorle\" OR \"barrette cioccolato\" OR \"special k\" OR \"kellogg barretta\" OR \"kellogg barrette\" OR \"latte cereali\" OR \"kellogg cereali\" OR #kelloggs OR #kellogs OR #naturalmentedeliziose OR #latteecereali OR #barrettaaicereali OR #barretteaicereali OR #specialk OR #kelloggsbarrette OR #kelloggsbarretta OR #kelloggscereali) (lang:it OR place_country:IT)","text":"( kelloggs OR kellogs OR barrette OR \"barrette cereali\" OR \"barrette mandorle\" OR \"barrette cioccolato\" OR \"special k\" OR \"kellogg barretta\" OR \"kellogg barrette\" OR \"latte cereali\" OR \"kellogg cereali\" OR #kelloggs OR #kellogs OR #naturalmentedeliziose OR #latteecereali OR 
# ...

# %%
df = df.rename(columns={'referralPath':'referral path','socialNetwork':'social network'})
# Out:
# {"type":"error","handler":"/middleware/authorize.js","value":"Authorization failed: no token found"}

# %%
from askdata.askdata_client import Askdata, Agent

#1. replace with token eg. Askdata(token=3453434-34542,env="dev") ... Askdata(token=23454234-45324,env="dev")
askdata = Askdata(token=token, env="dev")

#2. la get anche con agent ID  agent_id="s343-4534" Agent(askdata,agent_id="w345") ... Agent(askdata,"w345") ... Agent(askdata,agent_name="w345")
agent = Agent(askdata, agent_id=agentId)

# %%
#create dataset if the dataset exists
dataset_list = agent.load_datasets()
if (((dataset_list['name'] == 'Web Sources')).any() == False):
    #update and pass dataset ID
    agent.save_to_dataset(frame=df, dataset_name='Web Sources')
    
# need method to add syonym
# need method to add injection
# need method to create a channel with the alias
# need method to create insight
